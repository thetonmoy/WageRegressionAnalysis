# %%
import pandas as pd

# %%
data = pd.read_csv("DT-Wage.csv")

# %%
category_counts = data['region'].value_counts()
print(category_counts)
# Out:
# region
# 2. Middle Atlantic    3000
# Name: count, dtype: int64

# %%
data = data.drop('region', axis=1)
data
# Out:
#       year  age            maritl      race        education        jobclass  \
# 0     2006   18  1. Never Married  1. White     1. < HS Grad   1. Industrial
# 1     2004   24  1. Never Married  1. White  4. College Grad  2. Information
# 2     2003   45        2. Married  1. White  3. Some College   1. Industrial
# 3     2003   43        2. Married  3. Asian  4. College Grad  2. Information
# 4     2005   50       4. Divorced  1. White       2. HS Grad  2. Information
# ...    ...  ...               ...       ...              ...             ...
# 2995  2008   44        2. Married  1. White  3. Some College   1. Industrial
# 2996  2007   30        2. Married  1. White       2. HS Grad   1. Industrial
# 2997  2005   27        2. Married  2. Black     1. < HS Grad   1. Industrial
# 2998  2005   27  1. Never Married  1. White  3. Some College   1. Industrial
# 2999  2009   55      5. Separated  1. White       2. HS Grad   1. Industrial
#
# ...

# %%
category_counts = data['maritl'].value_counts()
print(category_counts)
# Out:
# maritl
# 2. Married          2074
# 1. Never Married     648
# 4. Divorced          204
# 5. Separated          55
# 3. Widowed            19
# Name: count, dtype: int64

# %%
data['maritl'] = data['maritl'].str.replace(r'^\d+\.\s*', '', regex=True)
data
# Out:
#       year  age         maritl      race     education        jobclass  \
# 0     2006   18  Never Married  1. White     < HS Grad   1. Industrial
# 1     2004   24  Never Married  1. White  College Grad  2. Information
# 2     2003   45        Married  1. White  Some College   1. Industrial
# 3     2003   43        Married  3. Asian  College Grad  2. Information
# 4     2005   50       Divorced  1. White       HS Grad  2. Information
# ...    ...  ...            ...       ...           ...             ...
# 2995  2008   44        Married  1. White  Some College   1. Industrial
# 2996  2007   30        Married  1. White       HS Grad   1. Industrial
# 2997  2005   27        Married  2. Black     < HS Grad   1. Industrial
# 2998  2005   27  Never Married  1. White  Some College   1. Industrial
# 2999  2009   55      Separated  1. White       HS Grad   1. Industrial
#
#               health health_ins   logwage        wage
# 0          1. <=Good      2. No  4.318063   75.043154
# ...

# %%
category_counts = data['maritl'].value_counts()
print(category_counts)
# Out:
# maritl
# Married          2074
# Never Married     648
# Divorced          204
# Separated          55
# Widowed            19
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data, columns=['maritl'], prefix='maritl')
data
# Out:
#       year  age      race     education        jobclass          health  \
# 0     2006   18  1. White     < HS Grad   1. Industrial       1. <=Good
# 1     2004   24  1. White  College Grad  2. Information  2. >=Very Good
# 2     2003   45  1. White  Some College   1. Industrial       1. <=Good
# 3     2003   43  3. Asian  College Grad  2. Information  2. >=Very Good
# 4     2005   50  1. White       HS Grad  2. Information       1. <=Good
# ...    ...  ...       ...           ...             ...             ...
# 2995  2008   44  1. White  Some College   1. Industrial  2. >=Very Good
# 2996  2007   30  1. White       HS Grad   1. Industrial  2. >=Very Good
# 2997  2005   27  2. Black     < HS Grad   1. Industrial       1. <=Good
# 2998  2005   27  1. White  Some College   1. Industrial  2. >=Very Good
# 2999  2009   55  1. White       HS Grad   1. Industrial       1. <=Good
#
#      health_ins   logwage        wage  maritl_Divorced  maritl_Married  \
# ...

# %%
category_counts = data['race'].value_counts()
print(category_counts)
# Out:
# race
# 1. White    2480
# 2. Black     293
# 3. Asian     190
# 4. Other      37
# Name: count, dtype: int64

# %%
category_counts = data['education'].value_counts()
print(category_counts)
# Out:
# education
# 2. HS Grad            971
# 4. College Grad       685
# 3. Some College       650
# 5. Advanced Degree    426
# 1. < HS Grad          268
# Name: count, dtype: int64

# %%
category_counts = data['jobclass'].value_counts()
print(category_counts)
# Out:
# jobclass
# 1. Industrial     1544
# 2. Information    1456
# Name: count, dtype: int64

# %%
category_counts = data['health'].value_counts()
print(category_counts)
# Out:
# health
# 2. >=Very Good    2142
# 1. <=Good          858
# Name: count, dtype: int64

# %%
category_counts = data['health_ins'].value_counts()
print(category_counts)
# Out:
# health_ins
# 1. Yes    2083
# 2. No      917
# Name: count, dtype: int64

# %%
import pandas as pd

# Assuming 'data' is your DataFrame
data['education'] = data['education'].str.replace(r'^\d+\.\s*', '', regex=True)
data
# Out:
#       year  age            maritl      race     education        jobclass  \
# 0     2006   18  1. Never Married  1. White     < HS Grad   1. Industrial
# 1     2004   24  1. Never Married  1. White  College Grad  2. Information
# 2     2003   45        2. Married  1. White  Some College   1. Industrial
# 3     2003   43        2. Married  3. Asian  College Grad  2. Information
# 4     2005   50       4. Divorced  1. White       HS Grad  2. Information
# ...    ...  ...               ...       ...           ...             ...
# 2995  2008   44        2. Married  1. White  Some College   1. Industrial
# 2996  2007   30        2. Married  1. White       HS Grad   1. Industrial
# 2997  2005   27        2. Married  2. Black     < HS Grad   1. Industrial
# 2998  2005   27  1. Never Married  1. White  Some College   1. Industrial
# 2999  2009   55      5. Separated  1. White       HS Grad   1. Industrial
#
#               health health_ins   logwage        wage
# ...
